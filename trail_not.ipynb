# %%
import numpy as np
import pandas as pd
from Quick_ML.BaseData import data

# %%
dt = data(pd.read_csv('data/placement.csv'))
# here we are using the Overview funfction
for i in dt.overview():
    print(i)
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   cgpa     200 non-null    float64
#  1   package  200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.3 KB
#
#              cgpa     package
# count  200.000000  200.000000
# mean     6.990500    2.996050
# std      1.069409    0.691644
# min      4.260000    1.370000
# 25%      6.190000    2.487500
# 50%      6.965000    2.995000
# 75%      7.737500    3.492500
# max      9.580000    4.620000

# %%
data.feature_transformation(
    # scaling is simple, cuz no need of any parameters, but for other we need to pass some parameters
    scaling = ('standard') ,
    # in encoding we have to pass the type of encoding and also the parameters for that encoding varies on the type of encoding
    # encoding = ('onehot', drop_first = True) ,
    # encoding = ('label'),
    encoding = ('ordinal', ['A','B','C']) ,
    # imputation is also simple, we just need to pass the type of imputation and the parameters for that imputation varies on the type of imputation
    # imputation = ('most_frequent'),
    # imputation = ('median'),
    # imputation = ('constant', fill_value = 0),
    # imputation = ('knn', n_neighbors = 5),
    # inputation = ('iterative', estimator = 'random_forest', max_iter = 10),
    imputation = ('mean'),
    outlier_detection =,
    outlier_treatment =

)
