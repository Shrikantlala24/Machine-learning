# %% [markdown]
# <a href="https://colab.research.google.com/github/Shrikantlala24/Machine-learning/blob/main/kaggle_dataset_loading.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
# !pip install opendatasets

# %%
import opendatasets as od
dataset = "https://www.kaggle.com/datasets/maharshipandya/-spotify-tracks-dataset"

# %%
od.download(dataset)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username:

# %%
df = pd.read_csv("/content/-spotify-tracks-dataset/dataset.csv")

# %%
df.head()
