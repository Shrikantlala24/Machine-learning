# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset('titanic')

# %%
from sklearn.impute import KNNImputer
ki = KNNImputer()

# n_neighbors=4 you can check

# %% [markdown]
# # nan-Euclidean
#  it handles if the values in columns are missing
# > it is by default

# %%
df.isnull().mean() *100
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
df['age2'] = ki.fit_transform(df[['age']])

# %%
df.sample(5)[['age','age2']]
# Out:
#       age       age2
# 354   NaN  29.699118
# 144  18.0  18.000000
# 358   NaN  29.699118
# 482  50.0  50.000000
# 386   1.0   1.000000
