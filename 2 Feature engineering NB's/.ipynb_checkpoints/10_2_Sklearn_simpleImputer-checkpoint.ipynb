# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
from sklearn.impute import SimpleImputer
si_mean = SimpleImputer(strategy='mean')
si_median = SimpleImputer(strategy='median')

# %%
df['age_mean'] = si_mean.fit_transform(df[['age']])
df['age_median'] = si_median.fit_transform(df[['age']])

# %%
# from sklearn.compose import ColumnTransformer
# ct = ColumnTransformer()

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# age_mean         0
# age_median       0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
si_mode = SimpleImputer(strategy='most_frequent')

# %%
embarked = si_mode.fit_transform(df[['embarked']])
# embarked

# %%
# pd.DataFrame(embarked)

# %%
sns.displot(df['embarked'],color='yellow')
sns.displot(pd.DataFrame(embarked)[0],color='red')
